# %%
import numpy as np
from sklearn.model_selection import KFold

# %%
import urllib.request
import zipfile
import pandas as pd

url = 'https://ssd.mathworks.com/supportfiles/nnet/data/TurbofanEngineDegradationSimulationData.zip'
urllib.request.urlretrieve(url, 'TurbofanEngineDegradationSimulationData.zip')
with zipfile.ZipFile('TurbofanEngineDegradationSimulationData.zip', 'r') as zip_ref:
    zip_ref.extractall()

degradationData = pd.read_csv('train_FD002.txt', delimiter='\s+')

# %%
degradationData.head(5)
# Out:
#    1  1.1  34.9983  0.8400  100.0  449.44  555.32  1358.61  1137.23  5.48  \
# 0  1    2  41.9982  0.8408  100.0  445.00  549.90  1353.22  1125.78  3.91
# 1  1    3  24.9988  0.6218   60.0  462.54  537.31  1256.76  1047.45  7.05
# 2  1    4  42.0077  0.8416  100.0  445.00  549.51  1354.03  1126.38  3.91
# 3  1    5  25.0005  0.6203   60.0  462.54  537.07  1257.71  1047.93  7.05
# 4  1    6  25.0045  0.6205   60.0  462.54  537.02  1266.38  1048.72  7.05
#
#    ...  183.06  2387.72  8048.56   9.3461  0.02  334  2223  100.00  14.73  \
# 0  ...  130.42  2387.66  8072.30   9.3774  0.02  330  2212  100.00  10.41
# 1  ...  164.22  2028.03  7864.87  10.8941  0.02  309  1915   84.93  14.08
# 2  ...  130.72  2387.61  8068.66   9.3528  0.02  329  2212  100.00  10.59
# 3  ...  164.31  2028.00  7861.23  10.8963  0.02  309  1915   84.93  14.13
# 4  ...  164.27  2028.01  7868.87  10.8912  0.02  306  1915   84.93  14.28
#
#    8.8071
# 0  6.2665
# 1  8.6723
# 2  6.4701
# 3  8.5286
# 4  8.5590
#
# ...
